# %%
monthly_sales.plot()
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()

# %%
import matplotlib.pyplot as plt

sales_by_product.plot(kind='bar')
plt.title("Sales by Product")
plt.xlabel("Product")
plt.ylabel("Total Sales")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
sales_by_region.plot(kind='bar')
plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.show()

# %%
monthly_sales = df.groupby(df['Date'].dt.to_period('M'))['Sales'].sum()
monthly_sales
# Out:
# Date
# 2024-01    78000
# 2024-02    27300
# 2024-03    97500
# Freq: M, Name: Sales, dtype: int64

# %%
sales_by_region = df.groupby('Region')['Sales'].sum()
sales_by_region
# Out:
# Region
# East     15000
# North    78500
# South    24300
# West     85000
# Name: Sales, dtype: int64

# %%
sales_by_product = df.groupby('Product')['Sales'].sum().sort_values(ascending=False)
sales_by_product
# Out:
# Product
# Laptop        115000
# Mobile         42000
# Tablet         25000
# Monitor        12000
# Headphones      6500
# Keyboard        1500
# Mouse            800
# Name: Sales, dtype: int64

# %%
total_sales = df['Sales'].sum()
total_sales
# Out:
# np.int64(202800)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# OrderID     0
# Date        0
# Product     0
# Category    0
# Sales       0
# Region      0
# dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OrderID   10 non-null     int64
#  1   Date      10 non-null     datetime64[ns]
#  2   Product   10 non-null     object
#  3   Category  10 non-null     object
#  4   Sales     10 non-null     int64
#  5   Region    10 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 612.0+ bytes

# %%
df.describe()
# Out:
#           OrderID         Sales
# count    10.00000     10.000000
# mean   1005.50000  20280.000000
# std       3.02765  21575.078215
# min    1001.00000    800.000000
# 25%    1003.25000   3125.000000
# 50%    1005.50000  16000.000000
# 75%    1007.75000  24250.000000
# max    1010.00000  60000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OrderID   10 non-null     int64
#  1   Date      10 non-null     object
#  2   Product   10 non-null     object
#  3   Category  10 non-null     object
#  4   Sales     10 non-null     int64
#  5   Region    10 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 612.0+ bytes

# %%
df.shape
# Out:
# (10, 6)

# %%
import pandas as pd

df = pd.read_csv("sales_data_sample.csv")
df.head()
# Out:
#    OrderID        Date     Product     Category  Sales Region
# 0     1001  2024-01-05      Laptop  Electronics  55000  North
# 1     1002  2024-01-07      Mobile  Electronics  20000  South
# 2     1003  2024-01-10  Headphones  Accessories   3000   East
# 3     1004  2024-02-02      Tablet  Electronics  25000   West
# 4     1005  2024-02-10    Keyboard  Accessories   1500  North

# %%
print("Finally working 🎉")
# Out:
# Finally working 🎉
